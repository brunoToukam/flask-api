# %%
# !pip install rake-nltk
# Out:
# Collecting rake-nltk
#   Downloading rake_nltk-1.0.6-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: nltk<4.0.0,>=3.6.2 in /home/bruno/anaconda3/lib/python3.9/site-packages (from rake-nltk) (3.6.5)
# Requirement already satisfied: click in /home/bruno/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (8.0.3)
# Requirement already satisfied: joblib in /home/bruno/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (1.1.0)
# Requirement already satisfied: regex>=2021.8.3 in /home/bruno/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (2021.8.3)
# Requirement already satisfied: tqdm in /home/bruno/anaconda3/lib/python3.9/site-packages (from nltk<4.0.0,>=3.6.2->rake-nltk) (4.62.3)
# Installing collected packages: rake-nltk
# Successfully installed rake-nltk-1.0.6

# %%
import pandas as pd
from rake_nltk import Rake
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import CountVectorizer
import nltk
nltk.download('stopwords')
nltk.download('punkt')

pd.set_option('display.max_columns', 200)
investors = pd.read_csv('/home/bruno/Downloads/investors.csv')
funding = pd.read_csv('/home/bruno/Downloads/funding-rounds.csv')
companies = pd.read_csv('/home/bruno/Downloads/companies.csv')
# Out:
# [nltk_data] Downloading package stopwords to /home/bruno/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/bruno/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
investors.head(2)
# Out:
#                Organization/Person Name  \
# 0                          Y Combinator
# 1  EASME - EU Executive Agency for SMEs
#
#                         Organization/Person Name URL      Investor Type  \
# 0  https://www.crunchbase.com/organization/y-comb...        Accelerator
# 1      https://www.crunchbase.com/organization/easme  Government Office
#
#   Number of Investments  Number of Exits  \
# 0                 4,203            398.0
# 1                 3,689            157.0
#
#                                             Location  \
# 0           Mountain View, California, United States
# 1  Brussels, Brussels Hoofdstedelijk Gewest, Belgium
#
#                                          Description  \
# 0  Y Combinator is a startup accelerator that inv...
# 1  EASME  is the European Union executive agency ...
#
#                                     Full Description
# 0  Y Combinator is a startup accelerator that inv...
# 1  The Executive Agency for Small and Medium-size...

# %%
companies.head()
# Out:
#    Organization Name                              Organization Name URL  \
# 0             KuCoin     https://www.crunchbase.com/organization/kucoin
# 1         TradeDepot  https://www.crunchbase.com/organization/traded...
# 2         MFS Africa  https://www.crunchbase.com/organization/mfs-af...
# 3  SWVL Technologies       https://www.crunchbase.com/organization/swvl
# 4             Yassir     https://www.crunchbase.com/organization/yassir
#
#                                           Industries  \
# 0  Bitcoin, Blockchain, Cryptocurrency, Finance, ...
# 1                    B2B, Consumer Goods, E-Commerce
# 2  Financial Services, FinTech, Mobile Payments, ...
# 3      Internet, Mobile Apps, Transportation, Travel
# 4       Apps, Information Technology, Transportation
#
#                            Headquarters Location  \
# 0                  Mahé, Beau Vallon, Seychelles
# 1                          Lagos, Lagos, Nigeria
# 2  Johannesburg, NA - South Africa, South Africa
# 3                       Cairo, Al Qahirah, Egypt
# 4                        Algiers, Alger, Algeria
#
#                                          Description CB Rank (Company)  \
# 0  Launched in 2017, KuCoin is a global cryptocur...                 8
# 1  TradeDepot is a B2B e-commerce and embedded fi...               172
# 2  MFS Africa is a digital payment company that o...               478
# 3  Swvl offers an app that allows customers to bo...               555
# 4  Yassir is a transport service that uses smartp...               746
#
#                                     Full Description
# 0  KuCoin is a global cryptocurrency exchange for...
# 1  TradeDepot is an end-to-end distribution platf...
# 2  MFS Africa is the largest mobile money inter-o...
# 3  Swvl is a premium mass transit system that pro...
# 4  Yassir is a transportation service that utiliz...

# %%
df = companies[['Industries', 'Headquarters Location', 'Description', 'Full Description']]

# %%
df.head(2)
# Out:
#                                           Industries  \
# 0  Bitcoin, Blockchain, Cryptocurrency, Finance, ...
# 1                    B2B, Consumer Goods, E-Commerce
#
#            Headquarters Location  \
# 0  Mahé, Beau Vallon, Seychelles
# 1          Lagos, Lagos, Nigeria
#
#                                          Description  \
# 0  Launched in 2017, KuCoin is a global cryptocur...
# 1  TradeDepot is a B2B e-commerce and embedded fi...
#
#                                     Full Description
# 0  KuCoin is a global cryptocurrency exchange for...
# 1  TradeDepot is an end-to-end distribution platf...

# %%
df['words'] = df['Industries'] + df['Headquarters Location'] + df['Description'] + df['Full Description']
# Out:
# /tmp/ipykernel_17268/3610051975.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['words'] = df['Industries'] + df['Headquarters Location'] + df['Description'] + df['Full Description']

# %%
df.head()
# Out:
#                                           Industries  \
# 0  Bitcoin, Blockchain, Cryptocurrency, Finance, ...
# 1                    B2B, Consumer Goods, E-Commerce
# 2  Financial Services, FinTech, Mobile Payments, ...
# 3      Internet, Mobile Apps, Transportation, Travel
# 4       Apps, Information Technology, Transportation
#
#                            Headquarters Location  \
# 0                  Mahé, Beau Vallon, Seychelles
# 1                          Lagos, Lagos, Nigeria
# 2  Johannesburg, NA - South Africa, South Africa
# 3                       Cairo, Al Qahirah, Egypt
# 4                        Algiers, Alger, Algeria
#
#                                          Description  \
# 0  Launched in 2017, KuCoin is a global cryptocur...
# 1  TradeDepot is a B2B e-commerce and embedded fi...
# 2  MFS Africa is a digital payment company that o...
# 3  Swvl offers an app that allows customers to bo...
# 4  Yassir is a transport service that uses smartp...
#
#                                     Full Description  \
# 0  KuCoin is a global cryptocurrency exchange for...
# 1  TradeDepot is an end-to-end distribution platf...
# 2  MFS Africa is the largest mobile money inter-o...
# 3  Swvl is a premium mass transit system that pro...
# 4  Yassir is a transportation service that utiliz...
#
#                                                words
# 0  Bitcoin, Blockchain, Cryptocurrency, Finance, ...
# 1  B2B, Consumer Goods, E-CommerceLagos, Lagos, N...
# 2  Financial Services, FinTech, Mobile Payments, ...
# 3  Internet, Mobile Apps, Transportation, TravelC...
# 4  Apps, Information Technology, TransportationAl...

# %%
df = df[['words']]

# %%
def transform_df(df):
    df['words'] = df['Industries'] + df['Headquarters Location'] + df['Description'] + df['Full Description']
    df = df[['Organization/Person Name'], ['words']]
    
    df['key_words'] = ""
    for index, row in df.iterrows():
        words = str(row['words'])
        r = Rake()
        r.extract_keywords_from_text(words)
        key_words_dict_scores = r.get_word_degrees()
        row['key_words'] = list(key_words_dict_scores.keys())
        df.key_words[index] = row['key_words']
    df.drop(columns=['words'], inplace=True)
    
    df['bag_of_words'] = ""
    for index, row in df.iterrows():
        df['bag_of_words'][index] = ' '.join(row['key_words'])
    df.drop(columns=['key_words'], inplace=True)
    
    df.set_index('Organization/Person Name', inplace=True)
    
    return df

# %%
df['key_words'] = ""
for index, row in df.iterrows():
    words = str(row['words'])
    r = Rake()
    r.extract_keywords_from_text(words)
    key_words_dict_scores = r.get_word_degrees()
    row['key_words'] = list(key_words_dict_scores.keys())
    df.key_words[index] = row['key_words']
df.drop(columns=['words'], inplace=True)

# %%
df.head()
# Out:
#                                            key_words
# 0  [bitcoin, blockchain, cryptocurrency, finance,...
# 1  [b2b, consumer, goods, e, commercelagos, lagos...
# 2  [financial, services, fintech, mobile, payment...
# 3  [internet, mobile, apps, transportation, trave...
# 4  [apps, information, technology, transportation...

# %%
df['bag_of_words'] = ""
for index, row in df.iterrows():
    df['bag_of_words'][index] = ' '.join(row['key_words'])
df.drop(columns=['key_words'], inplace=True)

# %%
def similarity(investor, companies):
    df = companies.append(investor)
    df['bag_of_words'] = ""
    for index, row in df.iterrows():
        df['bag_of_words'][index] = ' '.join(row['key_words'])
    df.drop(columns=['key_words'], inplace=True)
    
    count = CountVectorizer()
    count_matrix = count.fit_transform(df['bag_of_words'])
    
    cosine_sim = cosine_similarity(count_matrix, count_matrix)
    
    return cosine_sim

# %%
count = CountVectorizer()
count_matrix = count.fit_transform(df['bag_of_words'])

indices = pd.Series(df.index)
indices[:5]
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
cosine_sim = cosine_similarity(count_matrix, count_matrix)
cosine_sim
# Out:
# array([[1.        , 0.0287986 , 0.07993097, ..., 0.02185825, 0.10279279,
#         0.06779904],
#        [0.0287986 , 1.        , 0.14663103, ..., 0.02864166, 0.10775449,
#         0.03331483],
#        [0.07993097, 0.14663103, 1.        , ..., 0.        , 0.20935201,
#         0.04931511],
#        ...,
#        [0.02185825, 0.02864166, 0.        , ..., 1.        , 0.04089304,
#         0.01685739],
#        [0.10279279, 0.10775449, 0.20935201, ..., 0.04089304, 1.        ,
#         0.0634202 ],
#        [0.06779904, 0.03331483, 0.04931511, ..., 0.01685739, 0.0634202 ,
#         1.        ]])

# %%
df['bag_of_words'][0]
# Out:
# 'bitcoin blockchain cryptocurrency finance financial exchangesmahé beau vallon seychelleslaunched 2017 kucoin global exchange offering 400 digital assets providing crypto services 8m users numerous cryptocurrencies launched september grown one popular exchanges already 8 million registered across 207 countries regions around world known people ’ ", operates seychelles 24 7 multi language customer meanwhile established 19 local communities north america europe sea highly localized home gems supported 420 projects 790 trading pairs number like icp boson aergo rndr dao primary listing november 2018 announced 20 usd round funding idg capital matrix partners 2021 forbes advisor named best'

# %%
investors.head()
# Out:
#                Organization/Person Name  \
# 0                          Y Combinator
# 1  EASME - EU Executive Agency for SMEs
# 2                             Techstars
# 3                          500 Startups
# 4                         MassChallenge
#
#                         Organization/Person Name URL  \
# 0  https://www.crunchbase.com/organization/y-comb...
# 1      https://www.crunchbase.com/organization/easme
# 2  https://www.crunchbase.com/organization/techstars
# 3  https://www.crunchbase.com/organization/500-st...
# 4  https://www.crunchbase.com/organization/massch...
#
#                   Investor Type Number of Investments  Number of Exits  \
# 0                   Accelerator                 4,203            398.0
# 1             Government Office                 3,689            157.0
# 2  Accelerator, Venture Capital                 3,524            343.0
# 3  Accelerator, Venture Capital                 2,684            314.0
# 4                   Accelerator                 2,657            143.0
#
#                                             Location  \
# 0           Mountain View, California, United States
# 1  Brussels, Brussels Hoofdstedelijk Gewest, Belgium
# 2                   Boulder, Colorado, United States
# 3           San Francisco, California, United States
# 4               Boston, Massachusetts, United States
#
#                                          Description  \
# 0  Y Combinator is a startup accelerator that inv...
# 1  EASME  is the European Union executive agency ...
# 2  Techstars is a global platform that provides i...
# 3  500 Startups is a global venture capital firm ...
# 4  MassChallenge is a global non-profit startup a...
#
#                                     Full Description
# 0  Y Combinator is a startup accelerator that inv...
# 1  The Executive Agency for Small and Medium-size...
# 2  Techstars is a global platform that provides i...
# 3  500 Startups is a global venture capital firm ...
# 4  MassChallenge is the most startup-friendly acc...

# %%
def transform_companies(df):
    df['words'] = df['Industries'] + df['Headquarters Location'] + df['Description'] + df['Full Description']
    df = df[['Organization Name', 'words']]
    df = df.rename(columns={'Organization Name': 'Name'})
    
    df['key_words'] = ""
    for index, row in df.iterrows():
        words = str(row['words'])
        r = Rake()
        r.extract_keywords_from_text(words)
        key_words_dict_scores = r.get_word_degrees()
        row['key_words'] = list(key_words_dict_scores.keys())
        df.key_words[index] = row['key_words']
    df.drop(columns=['words'], inplace=True)
    
    df['bag_of_words'] = ""
    for index, row in df.iterrows():
        df['bag_of_words'][index] = ' '.join(row['key_words'])
    df.drop(columns=['key_words'], inplace=True)
    
    df.set_index('Name', inplace=True)
    
    return df

# %%
investors.head()
# Out:
#                Organization/Person Name  \
# 0                          Y Combinator
# 1  EASME - EU Executive Agency for SMEs
# 2                             Techstars
# 3                          500 Startups
# 4                         MassChallenge
#
#                         Organization/Person Name URL  \
# 0  https://www.crunchbase.com/organization/y-comb...
# 1      https://www.crunchbase.com/organization/easme
# 2  https://www.crunchbase.com/organization/techstars
# 3  https://www.crunchbase.com/organization/500-st...
# 4  https://www.crunchbase.com/organization/massch...
#
#                   Investor Type Number of Investments  Number of Exits  \
# 0                   Accelerator                 4,203            398.0
# 1             Government Office                 3,689            157.0
# 2  Accelerator, Venture Capital                 3,524            343.0
# 3  Accelerator, Venture Capital                 2,684            314.0
# 4                   Accelerator                 2,657            143.0
#
#                                             Location  \
# 0           Mountain View, California, United States
# 1  Brussels, Brussels Hoofdstedelijk Gewest, Belgium
# 2                   Boulder, Colorado, United States
# 3           San Francisco, California, United States
# 4               Boston, Massachusetts, United States
#
#                                          Description  \
# 0  Y Combinator is a startup accelerator that inv...
# 1  EASME  is the European Union executive agency ...
# 2  Techstars is a global platform that provides i...
# 3  500 Startups is a global venture capital firm ...
# 4  MassChallenge is a global non-profit startup a...
#
#                                     Full Description
# 0  Y Combinator is a startup accelerator that inv...
# 1  The Executive Agency for Small and Medium-size...
# 2  Techstars is a global platform that provides i...
# 3  500 Startups is a global venture capital firm ...
# 4  MassChallenge is the most startup-friendly acc...

# %%
def transform_investors(df):
    df['words'] = df['Investor Type'] + df['Location'] + df['Description'] + df['Full Description']
    df = df[['Organization/Person Name', 'words']]
    df = df.rename(columns={'Organization/Person Name': 'Name'})
    
    df['key_words'] = ""
    for index, row in df.iterrows():
        words = str(row['words'])
        r = Rake()
        r.extract_keywords_from_text(words)
        key_words_dict_scores = r.get_word_degrees()
        row['key_words'] = list(key_words_dict_scores.keys())
        df.key_words[index] = row['key_words']
    df.drop(columns=['words'], inplace=True)
    
    df['bag_of_words'] = ""
    for index, row in df.iterrows():
        df['bag_of_words'][index] = ' '.join(row['key_words'])
    df.drop(columns=['key_words'], inplace=True)
    
    df.set_index('Name', inplace=True)
    
    return df

# %%
def transform_investor(name, fundingType, location, description, fullDescription):
    data = {'Name': [name],
        'words': [fundingType + ' ' + description + ' ' + location + ' ' + fullDescription]}

    df = pd.DataFrame(data)
    
    df['key_words'] = ""
    for index, row in df.iterrows():
        words = str(row['words'])
        r = Rake()
        r.extract_keywords_from_text(words)
        key_words_dict_scores = r.get_word_degrees()
        row['key_words'] = list(key_words_dict_scores.keys())
        df.key_words[index] = row['key_words']
    df.drop(columns=['words'], inplace=True)
    
    df['bag_of_words'] = ""
    for index, row in df.iterrows():
        df['bag_of_words'][index] = ' '.join(row['key_words'])
    df.drop(columns=['key_words'], inplace=True)
    
    df.set_index('Name', inplace=True)
    
    return df

# %%
investors.head(2)
# Out:
#                Organization/Person Name  \
# 0                          Y Combinator
# 1  EASME - EU Executive Agency for SMEs
#
#                         Organization/Person Name URL      Investor Type  \
# 0  https://www.crunchbase.com/organization/y-comb...        Accelerator
# 1      https://www.crunchbase.com/organization/easme  Government Office
#
#   Number of Investments  Number of Exits  \
# 0                 4,203            398.0
# 1                 3,689            157.0
#
#                                             Location  \
# 0           Mountain View, California, United States
# 1  Brussels, Brussels Hoofdstedelijk Gewest, Belgium
#
#                                          Description  \
# 0  Y Combinator is a startup accelerator that inv...
# 1  EASME  is the European Union executive agency ...
#
#                                     Full Description
# 0  Y Combinator is a startup accelerator that inv...
# 1  The Executive Agency for Small and Medium-size...

# %%
descr = 'Y Combinator is a startup accelerator that invests in a large number of startups twice a year. It created a new model for funding early-stage startups. Twice a year, the company invests a small amount of money ($150k) in a large number of startups. The startup accelerator works intensively with the companies for three months, to get them into the best possible shape and refine their pitch to investors. Each cycle culminates in Demo Day when the startups present their companies to a carefully selected, invite-only audience.'

inv = transform_investor(
    name='Y Combinator', 
    fundingType='Accelerator', 
    location='Mountain View, California, United States',
    description='Y Combinator is a startup accelerator that invests in a wide range of startups twice a year.',
    fullDescription=descr)

# %%
inv
# Out:
#                                                    bag_of_words
# Name
# Y Combinator  accelerator combinator startup invests wide ra...

# %%
f = m.append(inv)

# %%
ind = pd.Series(f.index)
ind[:5]
# Out:
# 0               KuCoin
# 1           TradeDepot
# 2           MFS Africa
# 3    SWVL Technologies
# 4               Yassir
# Name: Name, dtype: object

# %%
i = ind[ind == 'MFS Africa'].index[0]

# %%
i
# Out:
# 2

# %%
def similarity(df):    
    count = CountVectorizer()
    count_matrix = count.fit_transform(df['bag_of_words'])
    
    cosine_sim = cosine_similarity(count_matrix, count_matrix)
    
    return cosine_sim

# %%
cos_sim
# Out:
# array([[1.        , 0.0287986 , 0.07993097, ..., 0.10279279, 0.06779904,
#         0.04539206],
#        [0.0287986 , 1.        , 0.14663103, ..., 0.10775449, 0.03331483,
#         0.05947887],
#        [0.07993097, 0.14663103, 1.        , ..., 0.20935201, 0.04931511,
#         0.04402255],
#        ...,
#        [0.10279279, 0.10775449, 0.20935201, ..., 1.        , 0.0634202 ,
#         0.02830693],
#        [0.06779904, 0.03331483, 0.04931511, ..., 0.0634202 , 1.        ,
#         0.058345  ],
#        [0.04539206, 0.05947887, 0.04402255, ..., 0.02830693, 0.058345  ,
#         1.        ]])

# %%
def recommendations(name, fundingType, location, description, fullDescription, df_companies):
    invest = transform_investor(name, fundingType, location, description, fullDescription)
    comp = transform_companies(df_companies)
    
    df = comp.append(invest)
    
    cosine_sim = similarity(df)
    
    indices = pd.Series(df.index)
    
    recommended_comp = []
    
    idx = indices[indices == name].index[0]
    
    score = pd.Series(cosine_sim[idx]).sort_values(ascending=False)
    # print('scores', score)
    
    top_10_indices = list(score.iloc[1:21].index)
    
    for i in top_10_indices:
        recommended_comp.append(list(df.index)[i])
    
    return recommended_comp

# %%
fullDescription = 'Y Combinator is a startup accelerator that invests in a large number of startups twice a year. It created a new model for funding early-stage startups. Twice a year, the company invests a small amount of money ($150k) in a large number of startups. The startup accelerator works intensively with the companies for three months, to get them into the best possible shape and refine their pitch to investors. Each cycle culminates in Demo Day when the startups present their companies to a carefully selected, invite-only audience.'
name='Y Combinator'
fundingType='Accelerator'
location='Mountain View, California, United States'
description='Y Combinator is a startup accelerator that invests in a wide range of startups twice a year.'

r = recommendations(name,fundingType, location,description,fullDescription,companies)

# %%
r
# Out:
# ['Microtraction',
#  'Algebra Ventures',
#  'Digest Africa',
#  'Bright On Capital',
#  'Prospa',
#  'Glade',
#  'Ingressive Capital',
#  'Afribon',
#  'The Baobab Network',
#  'Startup Circles.ai']

# %%
companies

# %%
kk = companies.copy()

# %%
filter = kk["Organization Name"]=="Microtraction"
  
# filtering data
kk.where(filter, inplace = True)

# %%
kk
# Out:
#      Organization Name                              Organization Name URL  \
# 0               KuCoin     https://www.crunchbase.com/organization/kucoin
# 1           TradeDepot  https://www.crunchbase.com/organization/traded...
# 2           MFS Africa  https://www.crunchbase.com/organization/mfs-af...
# 3    SWVL Technologies       https://www.crunchbase.com/organization/swvl
# 4               Yassir     https://www.crunchbase.com/organization/yassir
# ..                 ...                                                ...
# 995          iCog Labs  https://www.crunchbase.com/organization/icog-labs
# 996             SMEasy     https://www.crunchbase.com/organization/smeasy
# 997            Medixus    https://www.crunchbase.com/organization/medixus
# 998       Invoice Worx  https://www.crunchbase.com/organization/invoic...
# 999            Civicon    https://www.crunchbase.com/organization/civicon
#
#                                             Industries  \
# 0    Bitcoin, Blockchain, Cryptocurrency, Finance, ...
# 1                      B2B, Consumer Goods, E-Commerce
# 2    Financial Services, FinTech, Mobile Payments, ...
# 3        Internet, Mobile Apps, Transportation, Travel
# 4         Apps, Information Technology, Transportation
# ..                                                 ...
# 995  Artificial Intelligence, Biotechnology, Machin...
# 996  Accounting, Business Development, Small and Me...
# 997                     Health Care, Hospital, Medical
# 998   Enterprise, Finance, Financial Services, FinTech
# 999  Construction, Consulting, Industrial Engineeri...
#
#                              Headquarters Location  \
# 0                    Mahé, Beau Vallon, Seychelles
# 1                            Lagos, Lagos, Nigeria
# 2    Johannesburg, NA - South Africa, South Africa
# 3                         Cairo, Al Qahirah, Egypt
# 4                          Algiers, Alger, Algeria
# ..                                             ...
# 995              Addis Ababa, Adis Abeba, Ethiopia
# 996     Cape Town, NA - South Africa, South Africa
# 997                   Nairobi, Nairobi Area, Kenya
# 998       Gauteng, NA - South Africa, South Africa
# 999                          Mombasa, Coast, Kenya
#
#                                            Description CB Rank (Company)  \
# 0    Launched in 2017, KuCoin is a global cryptocur...                 8
# 1    TradeDepot is a B2B e-commerce and embedded fi...               172
# 2    MFS Africa is a digital payment company that o...               478
# 3    Swvl offers an app that allows customers to bo...               555
# 4    Yassir is a transport service that uses smartp...               746
# ..                                                 ...               ...
# 995  iCog Labs is a research and development compan...            82,507
# 996  SMEasy is a business management and accounting...            82,510
# 997  Medixus operates with patient care and the pro...            82,715
# 998  Invoice Worx is a working capital financing co...            82,740
# 999  Civicon is an engineering and construction com...            82,879
#
#                                       Full Description  \
# 0    KuCoin is a global cryptocurrency exchange for...
# 1    TradeDepot is an end-to-end distribution platf...
# 2    MFS Africa is the largest mobile money inter-o...
# 3    Swvl is a premium mass transit system that pro...
# 4    Yassir is a transportation service that utiliz...
# ..                                                 ...
# 995  iCog Labs is a research and development compan...
# 996  SMEasy is a business management and accounting...
# 997  Medixus operates with patient care and the pro...
# 998  Invoice Worx is a working capital financing co...
# 999  Civicon Limited has been in operation since 19...
#
#                                                  words
# 0    Bitcoin, Blockchain, Cryptocurrency, Finance, ...
# 1    B2B, Consumer Goods, E-CommerceLagos, Lagos, N...
# 2    Financial Services, FinTech, Mobile Payments, ...
# 3    Internet, Mobile Apps, Transportation, TravelC...
# 4    Apps, Information Technology, TransportationAl...
# ..                                                 ...
# 995  Artificial Intelligence, Biotechnology, Machin...
# 996  Accounting, Business Development, Small and Me...
# 997  Health Care, Hospital, MedicalNairobi, Nairobi...
# 998  Enterprise, Finance, Financial Services, FinTe...
# 999  Construction, Consulting, Industrial Engineeri...
#
# [1000 rows x 8 columns]

# %%
kk.loc[kk["Organization Name"]=="Microtraction"]
# Out:
#     Organization Name                              Organization Name URL  \
# 971     Microtraction  https://www.crunchbase.com/organization/microt...
#
#                                         Industries  Headquarters Location  \
# 971  Angel Investment, Finance, Financial Services  Lagos, Lagos, Nigeria
#
#                                            Description CB Rank (Company)  \
# 971  Microtraction invest in Africa's most remarkab...            80,802
#
#                                       Full Description  \
# 971  Microtraction is an investment platform that f...
#
#                                                  words
# 971  Angel Investment, Finance, Financial ServicesL...
